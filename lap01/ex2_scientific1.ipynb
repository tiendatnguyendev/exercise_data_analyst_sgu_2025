# %% [markdown]
# # ex2_scientific1
# ## Nội dung bài
# Hiển thị ngẫu nhiên $N=50$ hình tròn:
# + Tâm $c_i = (x_i,y_i)$ ngẫu nhiên với $x_i, y_i \in \left[0, 1 \right]$
# + Màu sắc $color_i$ ngẫu nhiên với $color_i \in \left[0, 1 \right]$
# + Diện tích $area_i = \pi * r_i^2$ với sinh ngẫu nhiên $r_i \in \left[0, 1 \right]$

# %% [markdown]
# ## Bài làm

# %% [markdown]
# ### Import thư viện

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display # hiển thị rich output

# %% [markdown]
# ### Sinh ngẫu nhiên hình tròn

# %%
# %time 
# sinh ngẫu nhiên khu vực, màu, hình tròn có (x, y)
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N)) ** 2 # 0 đến 15 điểm radii
# Out:
# CPU times: total: 0 ns
# Wall time: 223 μs

# %%
# mã tra tra dữ liệu
print(f' + x: len={len(x):d}, [{min(x):.2f}, {max(x):.2f}] : 10 samples [{x[0:10]}]')
print(f' + y: len={len(y):d}, [{min(y):.2f}, {max(y):.2f}] : 10 samples [{y[0:10]}]')
print(f' + colors: len={len(colors):d}, [{min(colors):.2f}, {max(x):.2f}] : 10 samples [{colors[0:10]}]')
print(f' + area: len={len(area):d}, [{min(area):.2f}, {max(area):.2f}] : 10 samples [{area[0:10]}]')
# Out:
#  + x: len=50, [0.03, 1.00] : 10 samples [[0.10610611 0.93476729 0.99836294 0.31805376 0.21661787 0.45898083
#  0.08606661 0.6544587  0.82071225 0.24646777]]
#  + y: len=50, [0.02, 0.96] : 10 samples [[0.31779511 0.75272256 0.45136295 0.22515708 0.90284818 0.44189524
#  0.19153084 0.1771591  0.27561229 0.65868755]]
#  + colors: len=50, [0.04, 1.00] : 10 samples [[0.67963029 0.99089243 0.341938   0.1746062  0.09563184 0.42011511
#  0.04179707 0.66495492 0.05692385 0.60983847]]
#  + area: len=50, [0.55, 696.42] : 10 samples [[584.85674966  16.80793196 667.56628606 296.80922764  57.44418849
#  140.41526784 508.83329239 569.11305893   4.59060593 105.71560161]]

# %% [markdown]
# ### Hiển thị đồ thị

# %%
# %matplotlib inline
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# # Kết thúc
